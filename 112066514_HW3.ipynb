# %% [markdown]
# <div align="center">
#
# # National Tsing Hua University
#
# ### Fall 2023
#
# #### 11210IPT 553000
#
# #### Deep Learning in Biomedical Optical Imaging
#
# ## HW3_Lab 4: Build a Convolution Neural Network
#
# </div>

# %%
# Download dataset
# !wget https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/normal.npy
# !wget https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/pneumonia.npy
# Out:
# --2023-10-30 12:45:01--  https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/normal.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65536128 (62M) [application/octet-stream]
# Saving to: ‘normal.npy’
#
# normal.npy          100%[===================>]  62.50M   332MB/s    in 0.2s
#
# 2023-10-30 12:45:03 (332 MB/s) - ‘normal.npy’ saved [65536128/65536128]
#
# --2023-10-30 12:45:03--  https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/train/pneumonia.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 65536128 (62M) [application/octet-stream]
# Saving to: ‘pneumonia.npy’
#
# pneumonia.npy       100%[===================>]  62.50M   289MB/s    in 0.2s
#
# 2023-10-30 12:45:05 (289 MB/s) - ‘pneumonia.npy’ saved [65536128/65536128]

# %% [markdown]
# ## A. Data Loading and Preprocessing
#
# In Convolutional Neural Networks (CNNs), the convolution operation expects the input to have a specific shape, typically denoted as `[batch_size, channels, height, width]`. The "channels" dimension refers to the number of input channels (or depth) of the input data.
#
# For standard RGB images, this channels value is 3 (for red, green, and blue). For grayscale images, there's only one channel. For more specialized data, there could be more channels. For example, medical imaging modalities like MRI or CT can sometimes have multiple channels representing different types of scans or different views of the same scan.
#
# When working with data that doesn't naturally have a channels dimension (e.g., plain grayscale image arrays that are just `[height, width]`), you need to explicitly add a channels dimension to match the expected input format of the CNN. This is done using `.unsqueeze(1)` which adds an additional dimension at the 1st position (0-indexed), converting a shape like `[batch_size, height, width]` to `[batch_size, 1, height, width]`. The "1" here indicates a single channel.

# %%
import torch
from torch.utils.data import DataLoader, TensorDataset, random_split

import numpy as np

# Load Dataset
abnormal_scans = np.load('pneumonia.npy')
normal_scans = np.load('normal.npy')

print(f'Shape of abnormal_scans: {abnormal_scans.shape}')
print(f'Shape of normal_scans: {normal_scans.shape}')

# For the data having presence of pneumonia assign 1, for the normal ones assign 0.

abnormal_labels = np.ones((abnormal_scans.shape[0],))
normal_labels = np.zeros((normal_scans.shape[0],))

split_point = 800

x_train = np.concatenate((abnormal_scans[:split_point], normal_scans[:split_point]), axis=0)
y_train = np.concatenate((abnormal_labels[:split_point], normal_labels[:split_point]), axis=0)
x_val = np.concatenate((abnormal_scans[split_point:], normal_scans[split_point:]), axis=0)
y_val = np.concatenate((abnormal_labels[split_point:], normal_labels[split_point:]), axis=0)

# Convert to PyTorch tensors
x_train = torch.from_numpy(x_train).float().unsqueeze(1) #unsqueeze
y_train = torch.from_numpy(y_train).long()
x_val = torch.from_numpy(x_val).float().unsqueeze(1)
y_val = torch.from_numpy(y_val).long()

# Create datasets
train_dataset = TensorDataset(x_train, y_train)
val_dataset = TensorDataset(x_val, y_val)

# Create dataloaders
train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

print(f'Number of samples in train and validation are {len(train_loader.dataset)} and {len(val_loader.dataset)}.')
print(f'X_train: max value is {x_train.max().item()}, min value is {x_train.min().item()}, data type is {x_train.dtype}.')
# Out:
# Shape of abnormal_scans: (1000, 256, 256)
# Shape of normal_scans: (1000, 256, 256)
# Number of samples in train and validation are 1600 and 400.
# X_train: max value is 255.0, min value is 0.0, data type is torch.float32.

# %% [markdown]
# ## B. Defining Neural Networks
#
# ### 1. Use the **Class**
#
# In PyTorch, we define our custom neural network architectures by subclassing the `nn.Module` class. This gives our neural network all the functionality it needs to work with PyTorch's other utilities and keeps our implementation organized.
#
# - Neural networks are defined by subclassing `nn.Module`.
# - The layers of the neural network are initialized in the `__init__` method.
# - The forward pass operations on input data are defined in the `forward` method.
#
# It's worth noting that while we only define the forward pass, PyTorch will automatically derive the backward pass for us, which is used during training to update the model's weights."

# %%
import torch.nn as nn
import torch.nn.functional as F

# model = nn.Sequential(
#     nn.Flatten(),
#     nn.Linear(256*256*1, 32), # 1st FC
#     nn.ReLU(),
#     nn.Linear(32, 32),        # 2nd FC 前面的數字要跟上一層後面數字一樣
#     nn.ReLU(),
#     nn.Linear(32, 32),        # 3rd FC
#     nn.ReLU(),
#     nn.Linear(32, 1)          # 4th FC 最後一層最後一個 output一定是1 (BCE)  n for n 類 CE
# ).cuda()

class LinearModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(256*256*1, 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 32)
        self.fc4 = nn.Linear(32, 1)

    def forward(self, x):
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        return self.fc4(x)
'''
# Add dropout to reduce the overfitting

class LinearModel(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.fc1 = nn.Linear(256*256*1, 32)
        self.fc2 = nn.Linear(32, 32)
        self.fc3 = nn.Linear(32, 32)
        self.fc4 = nn.Linear(32, 1)
        self.dropout = nn.Dropout(0.1)  # 創建一個dropout層，並在forward方法中應用

    def forward(self, x):
        x = self.flatten(x)
        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # 在fc1之後應用dropout
        x = F.relu(self.fc2(x))
        x = self.dropout(x)  # 在fc2之後應用dropout
        x = F.relu(self.fc3(x))
        x = self.dropout(x)  # 在fc3之後應用dropout
        return self.fc4(x)



'''
# Out:
# '\n# Add dropout to reduce the overfitting\n\nclass LinearModel(nn.Module):\n    def __init__(self):\n        super().__init__()\n        self.flatten = nn.Flatten()\n        self.fc1 = nn.Linear(256*256*1, 32)\n        self.fc2 = nn.Linear(32, 32)\n        self.fc3 = nn.Linear(32, 32)\n        self.fc4 = nn.Linear(32, 1)\n        self.dropout = nn.Dropout(0.1)  # 創建一個dropout層，並在forward方法中應用\n\n    def forward(self, x):\n        x = self.flatten(x)\n        x = F.relu(self.fc1(x))\n        x = self.dropout(x)  # 在fc1之後應用dropout\n        x = F.relu(self.fc2(x))\n        x = self.dropout(x)  # 在fc2之後應用dropout\n        x = F.relu(self.fc3(x))\n        x = self.dropout(x)  # 在fc3之後應用dropout\n        return self.fc4(x)\n\n\n\n'

# %% [markdown]
# ### 2. ann2cnn
#
# To transition a model from an ANN to a CNN using `nn.Conv2d` layers, we make the following changes:
#
# - Replace `nn.Linear` layers with `nn.Conv2d` layers for the initial layers.
# - Add pooling layers after convolutional layers for spatial dimension reduction.
# - Introduce a flattening step before transitioning to fully connected layers.
# - Adjust the `forward` method to handle the convolutional and pooling operations and reshaping.

# %%
import torch.nn as nn
import torch.nn.functional as F

class ConvModel(nn.Module):
    def __init__(self):
        super().__init__()

        # 1 channel, and using 3x3 kernels for simplicity, 256*256
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding='same')
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) # 128*128

        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding='same') # 128*128
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) # 64*64

        self.conv3 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding='same') # 64*64
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) # 32*32

        # Adjust flattened dimensions based on the output size of your last pooling layer
        flattened_dim = 32 * 32 * 32 #用算的 非任意; channel數 * 最後一層的 32 * 32  kernal size-1-原邊長

        self.fc1 = nn.Linear(flattened_dim, 32)
        self.fc2 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)

        x = F.relu(self.conv2(x))
        x = self.pool2(x)

        x = F.relu(self.conv3(x))
        x = self.pool3(x)

        # Flatten the output for the fully connected layers
        x = x.reshape(x.size(0), -1)  # x.size(0) is the batch size

        x = F.relu(self.fc1(x))
        return self.fc2(x)



class ConvModel_Re(nn.Module):
    def __init__(self):
        super().__init__()
        # 1 channel, and using 3x3 kernels for simplicity, 256*256
        self.conv1 = nn.Conv2d(1, 32, kernel_size=3, stride=1, padding=1)
        self.pool1 = nn.MaxPool2d(kernel_size=2, stride=2) # 128*128

        self.conv2 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1) # 128*128
        self.pool2 = nn.MaxPool2d(kernel_size=2, stride=2) # 64*64

        self.conv3 = nn.Conv2d(32, 32, kernel_size=3, stride=1, padding=1) # 64*64
        self.pool3 = nn.MaxPool2d(kernel_size=2, stride=2) # 32*32

        # Adjust flattened dimensions based on the output size of your last pooling layer
        flattened_dim = 32 * 32 * 32

        self.fc1 = nn.Linear(flattened_dim, 32)
        self.dropout = nn.Dropout(0.1)  # 添加dropout層
        self.fc2 = nn.Linear(32, 1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = self.pool1(x)

        x = F.relu(self.conv2(x))
        x = self.pool2(x)

        x = F.relu(self.conv3(x))
        x = self.pool3(x)
        # Flatten the output for the fully connected layers
        x = x.reshape(x.size(0), -1)

        x = F.relu(self.fc1(x))
        x = self.dropout(x)  # 在fc1之後應用dropout
        return self.fc2(x)

# %%
class ConvGAP(nn.Module):
    def __init__(self):
        super().__init__()

        self.net = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, stride=1, padding='same') ,
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2), # 128*128
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding='same'), # 128*128
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2), # 64*64
            nn.Conv2d(32, 32, kernel_size=3, stride=1, padding='same'), # 64*64
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2), # 32*32

            nn.AdaptiveAvgPool2d(1), ##這裡!!!!! 變圓變小 (就不用再用flatten了)
            nn.Flatten(),
            nn.Linear(32, 1)
        )

    def forward(self, x):

        x = self.net(x)
        return x

# %% [markdown]
# ## C. Training the Neural Network
#
# `model = model.cuda()` moves the model's parameters and buffers to the GPU memory.

# %%
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR, StepLR
from tqdm.auto import tqdm

train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

epochs = 200

# Change you model here
model =  ConvGAP()# LinearModel(), ConvModel(), ConvModel_Re !!!!!!這裡 可直接從這裡改架構
print(model)
model = model.cuda()

best_val_loss = float('inf')
best_val_acc = -1

criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3) #, weight_decay=0.1
lr_scheduler = CosineAnnealingLR(optimizer, T_max=len(train_loader)*epochs, eta_min=0)
#lr_scheduler = StepLR(optimizer, step_size=10, gamma=0.1)

for epoch in tqdm(range(epochs)):
    # Training
    model.train()
    total_loss = 0.0
    train_correct = 0
    total_train_samples = 0

    for images, labels in train_loader:
        images = images.cuda()
        images = images / 255.
        labels = labels.cuda()
        optimizer.zero_grad()
        outputs = model(images)

        labels = labels.float().unsqueeze(1)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()

        train_predicted = torch.sigmoid(outputs) > 0.5
        train_correct += (train_predicted.float() == labels).sum().item()
        total_train_samples += labels.size(0)

    avg_train_loss = total_loss / len(train_loader)
    train_accuracy = 100. * train_correct / total_train_samples

    # Validation
    model.eval()
    total_val_loss = 0.0
    correct = 0
    total = 0
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.cuda()
            images = images / 255.
            labels = labels.cuda()
            outputs = model(images)

            labels = labels.float().unsqueeze(1)

            loss = criterion(outputs, labels)
            total_val_loss += loss.item()

            predicted = torch.sigmoid(outputs) > 0.5
            correct += (predicted.float() == labels).sum().item()
            total += labels.size(0)

    avg_val_loss = total_val_loss / len(val_loader)
    val_accuracy = 100. * correct / total

    # Learning rate update
    lr_scheduler.step()

    # Checkpoint
    if avg_val_loss < best_val_loss:
        best_val_loss = avg_val_loss
        torch.save(model.state_dict(), 'model_classification.pth')

    if val_accuracy > best_val_acc:
        best_val_acc = val_accuracy

    print(f'Epoch {epoch+1}/{epochs}, Train loss: {avg_train_loss:.4f}, Train acc: {train_accuracy:.2f}%, Val loss: {avg_val_loss:.4f}, Val acc: {val_accuracy:.2f}%, Best Val loss: {best_val_loss:.4f} Best Val acc: {best_val_acc:.2f}%')

    # Store performance
    train_losses.append(avg_train_loss)
    train_accuracies.append(train_accuracy)
    val_losses.append(avg_val_loss)
    val_accuracies.append(val_accuracy)
# Out:
# ConvGAP(
#   (net): Sequential(
#     (0): Conv2d(1, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (4): ReLU()
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=same)
#     (7): ReLU()
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (9): AdaptiveAvgPool2d(output_size=1)
#     (10): Flatten(start_dim=1, end_dim=-1)
#     (11): Linear(in_features=32, out_features=1, bias=True)
#   )
# )
#   0%|          | 0/200 [00:00<?, ?it/s]
# Epoch 1/200, Train loss: 0.6942, Train acc: 49.50%, Val loss: 0.6917, Val acc: 63.25%, Best Val loss: 0.6917 Best Val acc: 63.25%
# Epoch 2/200, Train loss: 0.6909, Train acc: 54.00%, Val loss: 0.6824, Val acc: 50.25%, Best Val loss: 0.6824 Best Val acc: 63.25%
# Epoch 3/200, Train loss: 0.6826, Train acc: 62.94%, Val loss: 0.6584, Val acc: 70.25%, Best Val loss: 0.6584 Best Val acc: 70.25%
# Epoch 4/200, Train loss: 0.6613, Train acc: 69.25%, Val loss: 0.6219, Val acc: 74.00%, Best Val loss: 0.6219 Best Val acc: 74.00%
# Epoch 5/200, Train loss: 0.6388, Train acc: 69.12%, Val loss: 0.6387, Val acc: 58.00%, Best Val loss: 0.6219 Best Val acc: 74.00%
# Epoch 6/200, Train loss: 0.6173, Train acc: 69.38%, Val loss: 0.5790, Val acc: 74.25%, Best Val loss: 0.5790 Best Val acc: 74.25%
# Epoch 7/200, Train loss: 0.5878, Train acc: 71.81%, Val loss: 0.5314, Val acc: 77.00%, Best Val loss: 0.5314 Best Val acc: 77.00%
# Epoch 8/200, Train loss: 0.5765, Train acc: 72.19%, Val loss: 0.5429, Val acc: 79.50%, Best Val loss: 0.5314 Best Val acc: 79.50%
# Epoch 9/200, Train loss: 0.5580, Train acc: 74.31%, Val loss: 0.5240, Val acc: 80.25%, Best Val loss: 0.5240 Best Val acc: 80.25%
# Epoch 10/200, Train loss: 0.5265, Train acc: 76.94%, Val loss: 0.4965, Val acc: 77.00%, Best Val loss: 0.4965 Best Val acc: 80.25%
# Epoch 11/200, Train loss: 0.5064, Train acc: 78.38%, Val loss: 0.4751, Val acc: 79.50%, Best Val loss: 0.4751 Best Val acc: 80.25%
# Epoch 12/200, Train loss: 0.4901, Train acc: 78.00%, Val loss: 0.4409, Val acc: 83.75%, Best Val loss: 0.4409 Best Val acc: 83.75%
# Epoch 13/200, Train loss: 0.4378, Train acc: 82.94%, Val loss: 0.4030, Val acc: 86.75%, Best Val loss: 0.4030 Best Val acc: 86.75%
# Epoch 14/200, Train loss: 0.4256, Train acc: 83.00%, Val loss: 0.4006, Val acc: 88.00%, Best Val loss: 0.4006 Best Val acc: 88.00%
# Epoch 15/200, Train loss: 0.4294, Train acc: 82.88%, Val loss: 0.3755, Val acc: 84.25%, Best Val loss: 0.3755 Best Val acc: 88.00%
# Epoch 16/200, Train loss: 0.3788, Train acc: 86.44%, Val loss: 0.3313, Val acc: 90.00%, Best Val loss: 0.3313 Best Val acc: 90.00%
# Epoch 17/200, Train loss: 0.3720, Train acc: 85.88%, Val loss: 0.3508, Val acc: 89.50%, Best Val loss: 0.3313 Best Val acc: 90.00%
# Epoch 18/200, Train loss: 0.3707, Train acc: 86.06%, Val loss: 0.3286, Val acc: 90.50%, Best Val loss: 0.3286 Best Val acc: 90.50%
# Epoch 19/200, Train loss: 0.3404, Train acc: 87.75%, Val loss: 0.3071, Val acc: 91.25%, Best Val loss: 0.3071 Best Val acc: 91.25%
# Epoch 20/200, Train loss: 0.3054, Train acc: 89.00%, Val loss: 0.2905, Val acc: 91.00%, Best Val loss: 0.2905 Best Val acc: 91.25%
# Epoch 21/200, Train loss: 0.3191, Train acc: 88.31%, Val loss: 0.2843, Val acc: 90.75%, Best Val loss: 0.2843 Best Val acc: 91.25%
# Epoch 22/200, Train loss: 0.2961, Train acc: 89.69%, Val loss: 0.2581, Val acc: 91.50%, Best Val loss: 0.2581 Best Val acc: 91.50%
# Epoch 23/200, Train loss: 0.3036, Train acc: 88.38%, Val loss: 0.2848, Val acc: 91.25%, Best Val loss: 0.2581 Best Val acc: 91.50%
# Epoch 24/200, Train loss: 0.2878, Train acc: 89.38%, Val loss: 0.2512, Val acc: 92.25%, Best Val loss: 0.2512 Best Val acc: 92.25%
# Epoch 25/200, Train loss: 0.2686, Train acc: 90.25%, Val loss: 0.2454, Val acc: 92.00%, Best Val loss: 0.2454 Best Val acc: 92.25%
# Epoch 26/200, Train loss: 0.2963, Train acc: 89.44%, Val loss: 0.2682, Val acc: 91.25%, Best Val loss: 0.2454 Best Val acc: 92.25%
# Epoch 27/200, Train loss: 0.2831, Train acc: 89.75%, Val loss: 0.2530, Val acc: 92.25%, Best Val loss: 0.2454 Best Val acc: 92.25%
# Epoch 28/200, Train loss: 0.2798, Train acc: 89.75%, Val loss: 0.2864, Val acc: 90.00%, Best Val loss: 0.2454 Best Val acc: 92.25%
# Epoch 29/200, Train loss: 0.2794, Train acc: 90.00%, Val loss: 0.2765, Val acc: 90.50%, Best Val loss: 0.2454 Best Val acc: 92.25%
# Epoch 30/200, Train loss: 0.2628, Train acc: 90.44%, Val loss: 0.2964, Val acc: 88.75%, Best Val loss: 0.2454 Best Val acc: 92.25%
# Epoch 31/200, Train loss: 0.2601, Train acc: 90.06%, Val loss: 0.2339, Val acc: 92.25%, Best Val loss: 0.2339 Best Val acc: 92.25%
# Epoch 32/200, Train loss: 0.2619, Train acc: 90.62%, Val loss: 0.2382, Val acc: 91.75%, Best Val loss: 0.2339 Best Val acc: 92.25%
# Epoch 33/200, Train loss: 0.2522, Train acc: 90.12%, Val loss: 0.3089, Val acc: 87.75%, Best Val loss: 0.2339 Best Val acc: 92.25%
# Epoch 34/200, Train loss: 0.2538, Train acc: 90.44%, Val loss: 0.2358, Val acc: 92.50%, Best Val loss: 0.2339 Best Val acc: 92.50%
# Epoch 35/200, Train loss: 0.2505, Train acc: 90.62%, Val loss: 0.2290, Val acc: 93.00%, Best Val loss: 0.2290 Best Val acc: 93.00%
# Epoch 36/200, Train loss: 0.2532, Train acc: 90.94%, Val loss: 0.2520, Val acc: 91.25%, Best Val loss: 0.2290 Best Val acc: 93.00%
# Epoch 37/200, Train loss: 0.2458, Train acc: 90.81%, Val loss: 0.2519, Val acc: 92.50%, Best Val loss: 0.2290 Best Val acc: 93.00%
# Epoch 38/200, Train loss: 0.2648, Train acc: 90.38%, Val loss: 0.2881, Val acc: 89.50%, Best Val loss: 0.2290 Best Val acc: 93.00%
# Epoch 39/200, Train loss: 0.2571, Train acc: 90.50%, Val loss: 0.2253, Val acc: 92.25%, Best Val loss: 0.2253 Best Val acc: 93.00%
# Epoch 40/200, Train loss: 0.2320, Train acc: 90.94%, Val loss: 0.2219, Val acc: 92.50%, Best Val loss: 0.2219 Best Val acc: 93.00%
# Epoch 41/200, Train loss: 0.2380, Train acc: 90.69%, Val loss: 0.2280, Val acc: 92.50%, Best Val loss: 0.2219 Best Val acc: 93.00%
# Epoch 42/200, Train loss: 0.2364, Train acc: 91.31%, Val loss: 0.2685, Val acc: 90.00%, Best Val loss: 0.2219 Best Val acc: 93.00%
# Epoch 43/200, Train loss: 0.2450, Train acc: 90.75%, Val loss: 0.2289, Val acc: 93.25%, Best Val loss: 0.2219 Best Val acc: 93.25%
# Epoch 44/200, Train loss: 0.2375, Train acc: 91.44%, Val loss: 0.2266, Val acc: 91.75%, Best Val loss: 0.2219 Best Val acc: 93.25%
# Epoch 45/200, Train loss: 0.2343, Train acc: 90.88%, Val loss: 0.2188, Val acc: 92.25%, Best Val loss: 0.2188 Best Val acc: 93.25%
# Epoch 46/200, Train loss: 0.2255, Train acc: 91.94%, Val loss: 0.2318, Val acc: 91.00%, Best Val loss: 0.2188 Best Val acc: 93.25%
# Epoch 47/200, Train loss: 0.2344, Train acc: 91.25%, Val loss: 0.2154, Val acc: 93.25%, Best Val loss: 0.2154 Best Val acc: 93.25%
# Epoch 48/200, Train loss: 0.2304, Train acc: 91.19%, Val loss: 0.2439, Val acc: 93.25%, Best Val loss: 0.2154 Best Val acc: 93.25%
# Epoch 49/200, Train loss: 0.2249, Train acc: 91.31%, Val loss: 0.2521, Val acc: 90.50%, Best Val loss: 0.2154 Best Val acc: 93.25%
# Epoch 50/200, Train loss: 0.2238, Train acc: 91.50%, Val loss: 0.2094, Val acc: 93.75%, Best Val loss: 0.2094 Best Val acc: 93.75%
# Epoch 51/200, Train loss: 0.2105, Train acc: 92.19%, Val loss: 0.2546, Val acc: 89.50%, Best Val loss: 0.2094 Best Val acc: 93.75%
# Epoch 52/200, Train loss: 0.2217, Train acc: 92.06%, Val loss: 0.2135, Val acc: 92.00%, Best Val loss: 0.2094 Best Val acc: 93.75%
# Epoch 53/200, Train loss: 0.2218, Train acc: 91.69%, Val loss: 0.2160, Val acc: 93.00%, Best Val loss: 0.2094 Best Val acc: 93.75%
# Epoch 54/200, Train loss: 0.2208, Train acc: 91.50%, Val loss: 0.2323, Val acc: 90.75%, Best Val loss: 0.2094 Best Val acc: 93.75%
# Epoch 55/200, Train loss: 0.2064, Train acc: 91.94%, Val loss: 0.2350, Val acc: 92.25%, Best Val loss: 0.2094 Best Val acc: 93.75%
# Epoch 56/200, Train loss: 0.2056, Train acc: 92.31%, Val loss: 0.2001, Val acc: 93.50%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 57/200, Train loss: 0.1989, Train acc: 93.00%, Val loss: 0.2107, Val acc: 93.50%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 58/200, Train loss: 0.2150, Train acc: 91.31%, Val loss: 0.2074, Val acc: 92.75%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 59/200, Train loss: 0.2047, Train acc: 92.00%, Val loss: 0.2201, Val acc: 91.50%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 60/200, Train loss: 0.2075, Train acc: 92.19%, Val loss: 0.2059, Val acc: 93.50%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 61/200, Train loss: 0.2179, Train acc: 92.44%, Val loss: 0.2161, Val acc: 93.25%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 62/200, Train loss: 0.2062, Train acc: 92.31%, Val loss: 0.2072, Val acc: 93.25%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 63/200, Train loss: 0.2003, Train acc: 92.69%, Val loss: 0.2019, Val acc: 93.25%, Best Val loss: 0.2001 Best Val acc: 93.75%
# Epoch 64/200, Train loss: 0.1942, Train acc: 92.25%, Val loss: 0.1950, Val acc: 93.25%, Best Val loss: 0.1950 Best Val acc: 93.75%
# Epoch 65/200, Train loss: 0.1957, Train acc: 92.38%, Val loss: 0.2224, Val acc: 93.75%, Best Val loss: 0.1950 Best Val acc: 93.75%
# Epoch 66/200, Train loss: 0.2012, Train acc: 93.00%, Val loss: 0.2035, Val acc: 92.75%, Best Val loss: 0.1950 Best Val acc: 93.75%
# Epoch 67/200, Train loss: 0.1920, Train acc: 92.81%, Val loss: 0.2161, Val acc: 92.75%, Best Val loss: 0.1950 Best Val acc: 93.75%
# Epoch 68/200, Train loss: 0.1929, Train acc: 93.38%, Val loss: 0.2181, Val acc: 91.50%, Best Val loss: 0.1950 Best Val acc: 93.75%
# Epoch 69/200, Train loss: 0.1873, Train acc: 93.31%, Val loss: 0.2198, Val acc: 93.75%, Best Val loss: 0.1950 Best Val acc: 93.75%
# Epoch 70/200, Train loss: 0.2097, Train acc: 92.25%, Val loss: 0.2239, Val acc: 91.00%, Best Val loss: 0.1950 Best Val acc: 93.75%
# Epoch 71/200, Train loss: 0.1960, Train acc: 92.81%, Val loss: 0.1909, Val acc: 93.50%, Best Val loss: 0.1909 Best Val acc: 93.75%
# Epoch 72/200, Train loss: 0.1961, Train acc: 93.19%, Val loss: 0.2063, Val acc: 93.25%, Best Val loss: 0.1909 Best Val acc: 93.75%
# Epoch 73/200, Train loss: 0.1866, Train acc: 93.06%, Val loss: 0.2431, Val acc: 92.25%, Best Val loss: 0.1909 Best Val acc: 93.75%
# Epoch 74/200, Train loss: 0.1961, Train acc: 92.75%, Val loss: 0.2067, Val acc: 91.75%, Best Val loss: 0.1909 Best Val acc: 93.75%
# Epoch 75/200, Train loss: 0.1997, Train acc: 92.12%, Val loss: 0.1923, Val acc: 93.25%, Best Val loss: 0.1909 Best Val acc: 93.75%
# Epoch 76/200, Train loss: 0.1919, Train acc: 93.44%, Val loss: 0.1992, Val acc: 93.00%, Best Val loss: 0.1909 Best Val acc: 93.75%
# Epoch 77/200, Train loss: 0.1828, Train acc: 93.00%, Val loss: 0.1853, Val acc: 93.50%, Best Val loss: 0.1853 Best Val acc: 93.75%
# Epoch 78/200, Train loss: 0.1766, Train acc: 93.31%, Val loss: 0.2153, Val acc: 92.50%, Best Val loss: 0.1853 Best Val acc: 93.75%
# Epoch 79/200, Train loss: 0.1748, Train acc: 93.69%, Val loss: 0.1844, Val acc: 93.50%, Best Val loss: 0.1844 Best Val acc: 93.75%
# Epoch 80/200, Train loss: 0.1774, Train acc: 92.94%, Val loss: 0.2299, Val acc: 93.00%, Best Val loss: 0.1844 Best Val acc: 93.75%
# Epoch 81/200, Train loss: 0.1946, Train acc: 92.69%, Val loss: 0.2156, Val acc: 91.50%, Best Val loss: 0.1844 Best Val acc: 93.75%
# Epoch 82/200, Train loss: 0.1874, Train acc: 92.62%, Val loss: 0.1904, Val acc: 93.25%, Best Val loss: 0.1844 Best Val acc: 93.75%
# Epoch 83/200, Train loss: 0.1834, Train acc: 93.44%, Val loss: 0.1826, Val acc: 93.50%, Best Val loss: 0.1826 Best Val acc: 93.75%
# Epoch 84/200, Train loss: 0.1829, Train acc: 93.19%, Val loss: 0.1912, Val acc: 93.00%, Best Val loss: 0.1826 Best Val acc: 93.75%
# Epoch 85/200, Train loss: 0.1865, Train acc: 93.19%, Val loss: 0.1877, Val acc: 93.50%, Best Val loss: 0.1826 Best Val acc: 93.75%
# Epoch 86/200, Train loss: 0.1782, Train acc: 93.44%, Val loss: 0.1852, Val acc: 93.75%, Best Val loss: 0.1826 Best Val acc: 93.75%
# Epoch 87/200, Train loss: 0.1666, Train acc: 93.62%, Val loss: 0.1795, Val acc: 93.75%, Best Val loss: 0.1795 Best Val acc: 93.75%
# Epoch 88/200, Train loss: 0.1823, Train acc: 93.25%, Val loss: 0.1923, Val acc: 93.75%, Best Val loss: 0.1795 Best Val acc: 93.75%
# Epoch 89/200, Train loss: 0.1765, Train acc: 93.69%, Val loss: 0.1833, Val acc: 93.50%, Best Val loss: 0.1795 Best Val acc: 93.75%
# Epoch 90/200, Train loss: 0.1684, Train acc: 93.81%, Val loss: 0.1876, Val acc: 93.50%, Best Val loss: 0.1795 Best Val acc: 93.75%
# Epoch 91/200, Train loss: 0.1880, Train acc: 93.00%, Val loss: 0.1910, Val acc: 93.25%, Best Val loss: 0.1795 Best Val acc: 93.75%
# Epoch 92/200, Train loss: 0.1829, Train acc: 93.75%, Val loss: 0.1860, Val acc: 93.75%, Best Val loss: 0.1795 Best Val acc: 93.75%
# Epoch 93/200, Train loss: 0.1688, Train acc: 93.31%, Val loss: 0.1787, Val acc: 93.50%, Best Val loss: 0.1787 Best Val acc: 93.75%
# Epoch 94/200, Train loss: 0.1702, Train acc: 93.44%, Val loss: 0.1917, Val acc: 93.25%, Best Val loss: 0.1787 Best Val acc: 93.75%
# Epoch 95/200, Train loss: 0.1715, Train acc: 93.88%, Val loss: 0.1805, Val acc: 93.50%, Best Val loss: 0.1787 Best Val acc: 93.75%
# Epoch 96/200, Train loss: 0.1580, Train acc: 94.00%, Val loss: 0.1766, Val acc: 93.75%, Best Val loss: 0.1766 Best Val acc: 93.75%
# Epoch 97/200, Train loss: 0.1559, Train acc: 94.25%, Val loss: 0.1755, Val acc: 93.75%, Best Val loss: 0.1755 Best Val acc: 93.75%
# Epoch 98/200, Train loss: 0.1621, Train acc: 94.19%, Val loss: 0.2209, Val acc: 92.25%, Best Val loss: 0.1755 Best Val acc: 93.75%
# Epoch 99/200, Train loss: 0.1707, Train acc: 93.75%, Val loss: 0.1748, Val acc: 94.00%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 100/200, Train loss: 0.1587, Train acc: 94.12%, Val loss: 0.1856, Val acc: 93.50%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 101/200, Train loss: 0.1717, Train acc: 93.50%, Val loss: 0.1872, Val acc: 92.75%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 102/200, Train loss: 0.1616, Train acc: 94.00%, Val loss: 0.1801, Val acc: 93.50%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 103/200, Train loss: 0.1599, Train acc: 94.25%, Val loss: 0.1836, Val acc: 93.25%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 104/200, Train loss: 0.1579, Train acc: 94.50%, Val loss: 0.1804, Val acc: 93.25%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 105/200, Train loss: 0.1657, Train acc: 94.12%, Val loss: 0.1772, Val acc: 93.50%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 106/200, Train loss: 0.1543, Train acc: 95.12%, Val loss: 0.3530, Val acc: 85.50%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 107/200, Train loss: 0.1703, Train acc: 93.81%, Val loss: 0.2773, Val acc: 90.25%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 108/200, Train loss: 0.1602, Train acc: 94.38%, Val loss: 0.1935, Val acc: 93.50%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 109/200, Train loss: 0.1459, Train acc: 94.50%, Val loss: 0.2171, Val acc: 91.75%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 110/200, Train loss: 0.1630, Train acc: 93.69%, Val loss: 0.1752, Val acc: 93.25%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 111/200, Train loss: 0.1586, Train acc: 94.38%, Val loss: 0.2019, Val acc: 92.75%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 112/200, Train loss: 0.1586, Train acc: 94.31%, Val loss: 0.1811, Val acc: 93.50%, Best Val loss: 0.1748 Best Val acc: 94.00%
# Epoch 113/200, Train loss: 0.1487, Train acc: 94.56%, Val loss: 0.1740, Val acc: 93.25%, Best Val loss: 0.1740 Best Val acc: 94.00%
# Epoch 114/200, Train loss: 0.1533, Train acc: 94.56%, Val loss: 0.1968, Val acc: 92.50%, Best Val loss: 0.1740 Best Val acc: 94.00%
# Epoch 115/200, Train loss: 0.1496, Train acc: 94.44%, Val loss: 0.1722, Val acc: 93.50%, Best Val loss: 0.1722 Best Val acc: 94.00%
# Epoch 116/200, Train loss: 0.1465, Train acc: 94.38%, Val loss: 0.1986, Val acc: 93.00%, Best Val loss: 0.1722 Best Val acc: 94.00%
# Epoch 117/200, Train loss: 0.1489, Train acc: 94.69%, Val loss: 0.1704, Val acc: 93.75%, Best Val loss: 0.1704 Best Val acc: 94.00%
# Epoch 118/200, Train loss: 0.1488, Train acc: 94.38%, Val loss: 0.2093, Val acc: 92.50%, Best Val loss: 0.1704 Best Val acc: 94.00%
# Epoch 119/200, Train loss: 0.1452, Train acc: 94.50%, Val loss: 0.2123, Val acc: 92.25%, Best Val loss: 0.1704 Best Val acc: 94.00%
# Epoch 120/200, Train loss: 0.1460, Train acc: 94.81%, Val loss: 0.1735, Val acc: 93.50%, Best Val loss: 0.1704 Best Val acc: 94.00%
# Epoch 121/200, Train loss: 0.1567, Train acc: 93.81%, Val loss: 0.2141, Val acc: 92.50%, Best Val loss: 0.1704 Best Val acc: 94.00%
# Epoch 122/200, Train loss: 0.1469, Train acc: 94.81%, Val loss: 0.1943, Val acc: 93.00%, Best Val loss: 0.1704 Best Val acc: 94.00%
# Epoch 123/200, Train loss: 0.1434, Train acc: 94.50%, Val loss: 0.1671, Val acc: 94.25%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 124/200, Train loss: 0.1437, Train acc: 94.81%, Val loss: 0.1957, Val acc: 93.25%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 125/200, Train loss: 0.1411, Train acc: 95.12%, Val loss: 0.1701, Val acc: 93.75%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 126/200, Train loss: 0.1451, Train acc: 94.56%, Val loss: 0.1838, Val acc: 92.75%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 127/200, Train loss: 0.1407, Train acc: 94.69%, Val loss: 0.1835, Val acc: 93.75%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 128/200, Train loss: 0.1430, Train acc: 95.00%, Val loss: 0.1813, Val acc: 94.00%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 129/200, Train loss: 0.1474, Train acc: 94.19%, Val loss: 0.1955, Val acc: 92.00%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 130/200, Train loss: 0.1383, Train acc: 94.81%, Val loss: 0.1697, Val acc: 93.75%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 131/200, Train loss: 0.1311, Train acc: 95.19%, Val loss: 0.1671, Val acc: 94.00%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 132/200, Train loss: 0.1308, Train acc: 95.31%, Val loss: 0.1895, Val acc: 92.50%, Best Val loss: 0.1671 Best Val acc: 94.25%
# Epoch 133/200, Train loss: 0.1312, Train acc: 95.31%, Val loss: 0.1640, Val acc: 93.50%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 134/200, Train loss: 0.1260, Train acc: 95.56%, Val loss: 0.2051, Val acc: 91.25%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 135/200, Train loss: 0.1277, Train acc: 95.38%, Val loss: 0.1674, Val acc: 94.00%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 136/200, Train loss: 0.1282, Train acc: 95.38%, Val loss: 0.1773, Val acc: 93.50%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 137/200, Train loss: 0.1231, Train acc: 95.94%, Val loss: 0.1705, Val acc: 94.00%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 138/200, Train loss: 0.1358, Train acc: 95.25%, Val loss: 0.1710, Val acc: 94.00%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 139/200, Train loss: 0.1341, Train acc: 94.88%, Val loss: 0.1809, Val acc: 93.50%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 140/200, Train loss: 0.1373, Train acc: 95.44%, Val loss: 0.1809, Val acc: 93.75%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 141/200, Train loss: 0.1318, Train acc: 95.38%, Val loss: 0.1710, Val acc: 94.00%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 142/200, Train loss: 0.1228, Train acc: 95.81%, Val loss: 0.1745, Val acc: 93.75%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 143/200, Train loss: 0.1480, Train acc: 93.81%, Val loss: 0.2088, Val acc: 91.50%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 144/200, Train loss: 0.1415, Train acc: 94.38%, Val loss: 0.1836, Val acc: 93.50%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 145/200, Train loss: 0.1208, Train acc: 95.56%, Val loss: 0.1654, Val acc: 94.00%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 146/200, Train loss: 0.1237, Train acc: 95.38%, Val loss: 0.1641, Val acc: 93.75%, Best Val loss: 0.1640 Best Val acc: 94.25%
# Epoch 147/200, Train loss: 0.1197, Train acc: 96.25%, Val loss: 0.1636, Val acc: 93.50%, Best Val loss: 0.1636 Best Val acc: 94.25%
# Epoch 148/200, Train loss: 0.1201, Train acc: 95.69%, Val loss: 0.1848, Val acc: 92.75%, Best Val loss: 0.1636 Best Val acc: 94.25%
# Epoch 149/200, Train loss: 0.1190, Train acc: 95.44%, Val loss: 0.2281, Val acc: 90.25%, Best Val loss: 0.1636 Best Val acc: 94.25%
# Epoch 150/200, Train loss: 0.1301, Train acc: 95.50%, Val loss: 0.1651, Val acc: 93.75%, Best Val loss: 0.1636 Best Val acc: 94.25%
# Epoch 151/200, Train loss: 0.1242, Train acc: 95.62%, Val loss: 0.1635, Val acc: 94.25%, Best Val loss: 0.1635 Best Val acc: 94.25%
# Epoch 152/200, Train loss: 0.1181, Train acc: 96.06%, Val loss: 0.1617, Val acc: 93.50%, Best Val loss: 0.1617 Best Val acc: 94.25%
# Epoch 153/200, Train loss: 0.1230, Train acc: 95.81%, Val loss: 0.1706, Val acc: 94.00%, Best Val loss: 0.1617 Best Val acc: 94.25%
# Epoch 154/200, Train loss: 0.1199, Train acc: 96.00%, Val loss: 0.1678, Val acc: 94.25%, Best Val loss: 0.1617 Best Val acc: 94.25%
# Epoch 155/200, Train loss: 0.1202, Train acc: 95.81%, Val loss: 0.1631, Val acc: 93.75%, Best Val loss: 0.1617 Best Val acc: 94.25%
# Epoch 156/200, Train loss: 0.1233, Train acc: 95.38%, Val loss: 0.1794, Val acc: 93.25%, Best Val loss: 0.1617 Best Val acc: 94.25%
# Epoch 157/200, Train loss: 0.1165, Train acc: 96.00%, Val loss: 0.1712, Val acc: 93.75%, Best Val loss: 0.1617 Best Val acc: 94.25%
# Epoch 158/200, Train loss: 0.1186, Train acc: 96.06%, Val loss: 0.1612, Val acc: 93.25%, Best Val loss: 0.1612 Best Val acc: 94.25%
# Epoch 159/200, Train loss: 0.1215, Train acc: 95.56%, Val loss: 0.1650, Val acc: 93.25%, Best Val loss: 0.1612 Best Val acc: 94.25%
# Epoch 160/200, Train loss: 0.1351, Train acc: 94.56%, Val loss: 0.1728, Val acc: 93.50%, Best Val loss: 0.1612 Best Val acc: 94.25%
# Epoch 161/200, Train loss: 0.1133, Train acc: 95.94%, Val loss: 0.1577, Val acc: 93.75%, Best Val loss: 0.1577 Best Val acc: 94.25%
# Epoch 162/200, Train loss: 0.1091, Train acc: 96.25%, Val loss: 0.1560, Val acc: 93.50%, Best Val loss: 0.1560 Best Val acc: 94.25%
# Epoch 163/200, Train loss: 0.1058, Train acc: 96.31%, Val loss: 0.1610, Val acc: 94.50%, Best Val loss: 0.1560 Best Val acc: 94.50%
# Epoch 164/200, Train loss: 0.1449, Train acc: 95.06%, Val loss: 0.2591, Val acc: 90.75%, Best Val loss: 0.1560 Best Val acc: 94.50%
# Epoch 165/200, Train loss: 0.1267, Train acc: 95.69%, Val loss: 0.1757, Val acc: 93.25%, Best Val loss: 0.1560 Best Val acc: 94.50%
# Epoch 166/200, Train loss: 0.1118, Train acc: 96.31%, Val loss: 0.1673, Val acc: 93.25%, Best Val loss: 0.1560 Best Val acc: 94.50%
# Epoch 167/200, Train loss: 0.1123, Train acc: 96.19%, Val loss: 0.1756, Val acc: 93.75%, Best Val loss: 0.1560 Best Val acc: 94.50%
# Epoch 168/200, Train loss: 0.1136, Train acc: 95.81%, Val loss: 0.1724, Val acc: 93.75%, Best Val loss: 0.1560 Best Val acc: 94.50%
# Epoch 169/200, Train loss: 0.1180, Train acc: 95.75%, Val loss: 0.1557, Val acc: 93.75%, Best Val loss: 0.1557 Best Val acc: 94.50%
# Epoch 170/200, Train loss: 0.1076, Train acc: 96.12%, Val loss: 0.1789, Val acc: 94.00%, Best Val loss: 0.1557 Best Val acc: 94.50%
# Epoch 171/200, Train loss: 0.1073, Train acc: 96.38%, Val loss: 0.1569, Val acc: 94.25%, Best Val loss: 0.1557 Best Val acc: 94.50%
# Epoch 172/200, Train loss: 0.1134, Train acc: 96.12%, Val loss: 0.1924, Val acc: 92.75%, Best Val loss: 0.1557 Best Val acc: 94.50%
# Epoch 173/200, Train loss: 0.1179, Train acc: 95.62%, Val loss: 0.1546, Val acc: 94.25%, Best Val loss: 0.1546 Best Val acc: 94.50%
# Epoch 174/200, Train loss: 0.1331, Train acc: 95.62%, Val loss: 0.1755, Val acc: 92.75%, Best Val loss: 0.1546 Best Val acc: 94.50%
# Epoch 175/200, Train loss: 0.1026, Train acc: 96.81%, Val loss: 0.1533, Val acc: 94.25%, Best Val loss: 0.1533 Best Val acc: 94.50%
# Epoch 176/200, Train loss: 0.1151, Train acc: 96.31%, Val loss: 0.1702, Val acc: 93.50%, Best Val loss: 0.1533 Best Val acc: 94.50%
# Epoch 177/200, Train loss: 0.1072, Train acc: 95.62%, Val loss: 0.1651, Val acc: 93.50%, Best Val loss: 0.1533 Best Val acc: 94.50%
# Epoch 178/200, Train loss: 0.1033, Train acc: 96.81%, Val loss: 0.1523, Val acc: 94.00%, Best Val loss: 0.1523 Best Val acc: 94.50%
# Epoch 179/200, Train loss: 0.0997, Train acc: 96.38%, Val loss: 0.1531, Val acc: 93.75%, Best Val loss: 0.1523 Best Val acc: 94.50%
# Epoch 180/200, Train loss: 0.1074, Train acc: 96.38%, Val loss: 0.1507, Val acc: 94.25%, Best Val loss: 0.1507 Best Val acc: 94.50%
# Epoch 181/200, Train loss: 0.1150, Train acc: 96.06%, Val loss: 0.1589, Val acc: 93.75%, Best Val loss: 0.1507 Best Val acc: 94.50%
# Epoch 182/200, Train loss: 0.1008, Train acc: 96.94%, Val loss: 0.1590, Val acc: 93.50%, Best Val loss: 0.1507 Best Val acc: 94.50%
# Epoch 183/200, Train loss: 0.1087, Train acc: 96.00%, Val loss: 0.1509, Val acc: 94.25%, Best Val loss: 0.1507 Best Val acc: 94.50%
# Epoch 184/200, Train loss: 0.0967, Train acc: 96.44%, Val loss: 0.2029, Val acc: 92.00%, Best Val loss: 0.1507 Best Val acc: 94.50%
# Epoch 185/200, Train loss: 0.1072, Train acc: 95.88%, Val loss: 0.1515, Val acc: 94.75%, Best Val loss: 0.1507 Best Val acc: 94.75%
# Epoch 186/200, Train loss: 0.1097, Train acc: 96.19%, Val loss: 0.1519, Val acc: 94.25%, Best Val loss: 0.1507 Best Val acc: 94.75%
# Epoch 187/200, Train loss: 0.0966, Train acc: 96.88%, Val loss: 0.1638, Val acc: 93.75%, Best Val loss: 0.1507 Best Val acc: 94.75%
# Epoch 188/200, Train loss: 0.1094, Train acc: 95.69%, Val loss: 0.1469, Val acc: 94.25%, Best Val loss: 0.1469 Best Val acc: 94.75%
# Epoch 189/200, Train loss: 0.1044, Train acc: 96.12%, Val loss: 0.1572, Val acc: 93.50%, Best Val loss: 0.1469 Best Val acc: 94.75%
# Epoch 190/200, Train loss: 0.0971, Train acc: 96.44%, Val loss: 0.1491, Val acc: 95.00%, Best Val loss: 0.1469 Best Val acc: 95.00%
# Epoch 191/200, Train loss: 0.0936, Train acc: 96.44%, Val loss: 0.1979, Val acc: 92.00%, Best Val loss: 0.1469 Best Val acc: 95.00%
# Epoch 192/200, Train loss: 0.1065, Train acc: 96.25%, Val loss: 0.1536, Val acc: 93.75%, Best Val loss: 0.1469 Best Val acc: 95.00%
# Epoch 193/200, Train loss: 0.0947, Train acc: 96.88%, Val loss: 0.1507, Val acc: 93.75%, Best Val loss: 0.1469 Best Val acc: 95.00%
# Epoch 194/200, Train loss: 0.1254, Train acc: 95.25%, Val loss: 0.1457, Val acc: 94.25%, Best Val loss: 0.1457 Best Val acc: 95.00%
# Epoch 195/200, Train loss: 0.1014, Train acc: 96.31%, Val loss: 0.1646, Val acc: 94.25%, Best Val loss: 0.1457 Best Val acc: 95.00%
# Epoch 196/200, Train loss: 0.0968, Train acc: 96.44%, Val loss: 0.1769, Val acc: 93.25%, Best Val loss: 0.1457 Best Val acc: 95.00%
# Epoch 197/200, Train loss: 0.1063, Train acc: 96.69%, Val loss: 0.1962, Val acc: 92.00%, Best Val loss: 0.1457 Best Val acc: 95.00%
# Epoch 198/200, Train loss: 0.1045, Train acc: 96.31%, Val loss: 0.1513, Val acc: 94.00%, Best Val loss: 0.1457 Best Val acc: 95.00%
# Epoch 199/200, Train loss: 0.0935, Train acc: 96.69%, Val loss: 0.1410, Val acc: 94.75%, Best Val loss: 0.1410 Best Val acc: 95.00%
# Epoch 200/200, Train loss: 0.1018, Train acc: 96.44%, Val loss: 0.1467, Val acc: 94.25%, Best Val loss: 0.1410 Best Val acc: 95.00%

# %% [markdown]
# ### Visualizing model performance

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1, 2, figsize=(15, 5))

# Plotting training and validation accuracy
ax[0].plot(train_accuracies)
ax[0].plot(val_accuracies)
ax[0].set_title('Model Accuracy')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Accuracy')
ax[0].legend(['Train', 'Val'])

# Plotting training and validation loss
ax[1].plot(train_losses)
ax[1].plot(val_losses)
ax[1].set_title('Model Loss')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Loss')
ax[1].legend(['Train', 'Val'])

plt.show()

# %% [markdown]
# ## D. Evaluating Your Trained Model

# %%
# !wget https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/test/test_normal.npy
# !wget https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/test/test_pneumonia.npy
# Out:
# --2023-10-30 13:01:53--  https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/test/test_normal.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13107328 (12M) [application/octet-stream]
# Saving to: ‘test_normal.npy’
#
# test_normal.npy     100%[===================>]  12.50M  --.-KB/s    in 0.07s
#
# 2023-10-30 13:01:54 (184 MB/s) - ‘test_normal.npy’ saved [13107328/13107328]
#
# --2023-10-30 13:01:54--  https://raw.githubusercontent.com/TacoXDD/homeworks/master/dataset/test/test_pneumonia.npy
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13107328 (12M) [application/octet-stream]
# Saving to: ‘test_pneumonia.npy’
#
# test_pneumonia.npy  100%[===================>]  12.50M  --.-KB/s    in 0.07s
#
# 2023-10-30 13:01:54 (178 MB/s) - ‘test_pneumonia.npy’ saved [13107328/13107328]

# %% [markdown]
# ### Process Test Dataset

# %%
test_abnormal = np.load('test_pneumonia.npy')
test_normal = np.load('test_normal.npy')

print(f'Shape of test_abnormal: {test_abnormal.shape}')
print(f'Shape of test_normal: {test_normal.shape}')

# For the data having presence of pneumonia assign 1, for the normal ones assign 0.
test_abnormal_labels = np.ones((test_abnormal.shape[0],))
test_normal_labels = np.zeros((test_normal.shape[0],))

x_test = np.concatenate((test_abnormal, test_normal), axis=0)
y_test = np.concatenate((test_abnormal_labels, test_normal_labels), axis=0)

print(f'Shape of x_test: {x_test.shape}')
print(f'Shape of y_test: {y_test.shape}')


# Convert to PyTorch tensors
x_test = torch.from_numpy(x_test).float().unsqueeze(1)
y_test = torch.from_numpy(y_test).long()

# Combine the images and labels into a dataset
test_dataset = TensorDataset(x_test, y_test)

# Create a dataloader to load data in batches. Set batch size to 32.
test_loader = DataLoader(test_dataset, 32, shuffle=False)
# Out:
# Shape of test_abnormal: (200, 256, 256)
# Shape of test_normal: (200, 256, 256)
# Shape of x_test: (400, 256, 256)
# Shape of y_test: (400,)

# %% [markdown]
# ### Load Trained Model and Evaluate

# %%
# Load the trained weights
model.load_state_dict(torch.load('model_classification.pth'))

# Set the model to evaluation mode
model.eval()

test_correct = 0
test_total = 0

with torch.no_grad():
    for images, labels in test_loader:

        images = images.cuda()
        images = images / 255.

        labels = labels.cuda()

        outputs = model(images)

        labels_float = labels.float().unsqueeze(1)  # Convert labels to float and match shape with outputs
        predicted = torch.sigmoid(outputs) > 0.5

        test_correct += (predicted.float() == labels_float).sum().item()
        test_total += labels.size(0)

print(f'Test accuracy is {100. * test_correct / test_total}%')
# Out:
# Test accuracy is 70.0%
